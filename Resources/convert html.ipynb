# %%
import pandas as pd

# %%
df = pd.read_csv("cities.csv")

# %%
htl=df.to_html(index=False)

# %%
print(htl)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Unnamed: 0</th>
#       <th>City</th>
#       <th>Lats</th>
#       <th>Lngs</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>Nikolskoye</td>
#       <td>59.7035</td>
#       <td>30.7861</td>
#       <td>18.77</td>
#       <td>82</td>
#       <td>49</td>
#       <td>1.17</td>
#       <td>RU</td>
#       <td>1659555815</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>Busselton</td>
#       <td>-33.6500</td>
#       <td>115.3333</td>
#       <td>11.89</td>
#       <td>73</td>
#       <td>95</td>
#       <td>8.35</td>
#       <td>AU</td>
#       <td>1659555816</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>Mataura</td>
#       <td>-46.1927</td>
#       <td>168.8643</td>
# ...
